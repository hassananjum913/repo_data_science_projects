# %%
! pip install beautifulsoup4

# %%
# !pip install requests

# %%
import sys
import time
from bs4 import BeautifulSoup
import requests

# %%
try:
    page = requests.get('https://www.cricbuzz.com/')     # source website

except Exception as e:                                         # exception handling
    error_type , error_obj , error_info = sys.exc_info()
    
    print('Error for link :', url)
    
    print(error_type , 'Line : ', error_info.tb_lineno)
    

time.sleep(2)

soup = BeautifulSoup(page.text, 'html.parser') # scraped text from html

links = soup.find_all('div', attrs={'class':'cb-nws-intr'})    # scarped specific links from text

# %%
# no exceptions thrown

sys.exc_info()
# Out:
# (None, None, None)

# %%
page   # reponse = 200 (success)
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
links
# Out:
# [<div class="cb-nws-intr">BCCI has enforced a two-week quarantine for the travelling contingent before they leave for England, likely on June 2</div>,
#  <div class="cb-nws-intr">Ashley Giles, ECB's director of men's cricket, confirmed that the ECB did not consider pulling their players home earlier from the IPL as the situation in India worsened</div>,
#  <div class="cb-nws-intr">Should he play all three Tests on the tour, he'll surpass Adam Parore as New Zealand's most-capped Test keeper</div>,
#  <div class="cb-nws-intr">In his review of the team's tour of Africa, Pakistan's head coach also lambasted the ageist criticism of Tabish Khan's selection</div>,
#  <div class="cb-nws-intr">In a detailed conversation with Cricbuzz Plus, Gary Kirsten dives deep into his coaching processes, and what has led him to have success in some roles but not in others</div>,
#  <div class="cb-nws-intr">Liton Das, currently going through a rough patch, attempts to reinvent himself in the nets</div>,
# ...

# %%
for i in links:  # extracting text excluding html tags
    print(i.text)
    print('\n')
# Out:
# BCCI has enforced a two-week quarantine for the travelling contingent before they leave for England, likely on June 2
#
#
# Ashley Giles, ECB's director of men's cricket, confirmed that the ECB did not consider pulling their players home earlier from the IPL as the situation in India worsened
#
#
# Should he play all three Tests on the tour, he'll surpass Adam Parore as New Zealand's most-capped Test keeper
#
#
# In his review of the team's tour of Africa, Pakistan's head coach also lambasted the ageist criticism of Tabish Khan's selection
#
#
# In a detailed conversation with Cricbuzz Plus, Gary Kirsten dives deep into his coaching processes, and what has led him to have success in some roles but not in others
#
#
# Liton Das, currently going through a rough patch, attempts to reinvent himself in the nets
#
#
# In the latest edition of The Think Tank on Cricbuzz Plus, we look at the difficult question of who owns cricket
#
#
# ...
